# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# %%
# Read CSV file into DF
airline_df = pd.read_csv("Resources/Airline_Delay_cause.csv")

# Display beggining of DataFrame
airline_df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# 1        7.38        0.00  ...          0.0              6.09            0.0
# 2        0.13        0.00  ...          0.0              0.88            1.0
# 3        7.26        0.76  ...          0.0              1.64            0.0
# 4       13.84        0.00  ...          0.0              2.09            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %%
# Display DataFrame Info
airline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318017 non-null  object
#  3   carrier_name         318017 non-null  object
#  4   airport              318017 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317529 non-null  float64
#  7   arr_del15            317289 non-null  float64
#  8   carrier_ct           317529 non-null  float64
#  9   weather_ct           317529 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
#  14  arr_diverted         317529 non-null  float64
#  15  arr_delay            317529 non-null  float64
#  16  carrier_delay        317529 non-null  float64
#  17  weather_delay        317529 non-null  float64
#  18  nas_delay            317529 non-null  float64
#  19  security_delay       317529 non-null  float64
#  20  late_aircraft_delay  317529 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 51.0+ MB

# %%
# Drop non-null values
airline_clean_df = airline_df.dropna()
airline_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317289 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 317289 non-null  int64
#  1   month                317289 non-null  int64
#  2   carrier              317289 non-null  object
#  3   carrier_name         317289 non-null  object
#  4   airport              317289 non-null  object
#  5   airport_name         317289 non-null  object
#  6   arr_flights          317289 non-null  float64
#  7   arr_del15            317289 non-null  float64
#  8   carrier_ct           317289 non-null  float64
#  9   weather_ct           317289 non-null  float64
#  10  nas_ct               317289 non-null  float64
#  11  security_ct          317289 non-null  float64
#  12  late_aircraft_ct     317289 non-null  float64
#  13  arr_cancelled        317289 non-null  float64
#  14  arr_diverted         317289 non-null  float64
#  15  arr_delay            317289 non-null  float64
#  16  carrier_delay        317289 non-null  float64
#  17  weather_delay        317289 non-null  float64
#  18  nas_delay            317289 non-null  float64
#  19  security_delay       317289 non-null  float64
#  20  late_aircraft_delay  317289 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 53.3+ MB

# %%
airline_clean_df
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 318012  2003      6      DL  Delta Air Lines Inc.     SEA
# 318013  2003      6      DL  Delta Air Lines Inc.     SFO
# 318014  2003      6      DL  Delta Air Lines Inc.     SJC
# 318015  2003      6      DL  Delta Air Lines Inc.     SJU
# 318016  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# 2                       Nantucket, MA: Nantucket Memorial         19.0
# 3                Alexandria, LA: Alexandria International         88.0
# 4             Augusta, GA: Augusta Regional at Bush Field        181.0
# ...                                                   ...          ...
# 318012          Seattle, WA: Seattle/Tacoma International        480.0
# 318013     San Francisco, CA: San Francisco International        505.0
# 318014  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 318015       San Juan, PR: Luis Munoz Marin International         95.0
# 318016   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0             7.0        5.95        0.00  ...          0.0              1.00
# 1            16.0        7.38        0.00  ...          0.0              6.09
# 2             2.0        0.13        0.00  ...          0.0              0.88
# 3            14.0        7.26        0.76  ...          0.0              1.64
# 4            19.0       13.84        0.00  ...          0.0              2.09
# ...           ...         ...         ...  ...          ...               ...
# 318012       84.0       25.69        3.09  ...          0.0             21.26
# 318013      111.0       21.78        2.24  ...          0.0             13.17
# 318014       36.0        6.99        0.00  ...          0.0              2.15
# 318015       13.0        3.66        0.00  ...          0.0              1.42
# 318016      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0                 0.0           0.0      255.0          222.0            0.0
# 1                 0.0           0.0      884.0          351.0            0.0
# 2                 1.0           0.0      138.0            4.0            0.0
# 3                 0.0           0.0      947.0          585.0           35.0
# 4                 0.0           0.0      808.0          662.0            0.0
# ...               ...           ...        ...            ...            ...
# 318012            0.0           0.0     3744.0          978.0          164.0
# 318013            3.0           0.0     4284.0         1376.0          138.0
# 318014            0.0           0.0      896.0          205.0            0.0
# 318015            0.0           0.0      367.0          120.0            0.0
# 318016            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 0             4.0             0.0                 29.0
# 1            81.0             0.0                452.0
# 2           106.0             0.0                 28.0
# 3           125.0             0.0                202.0
# 4            87.0             0.0                 59.0
# ...           ...             ...                  ...
# 318012     1023.0             0.0               1579.0
# 318013     2132.0             0.0                638.0
# 318014      607.0             0.0                 84.0
# 318015      210.0             0.0                 37.0
# 318016     5686.0            28.0               5449.0
#
# [317289 rows x 21 columns]

# %%
airline_clean_df['carrier_name'].unique()
# Out:
# array(['Endeavor Air Inc.', 'American Airlines Inc.',
#        'Alaska Airlines Inc.', 'JetBlue Airways', 'Delta Air Lines Inc.',
#        'Frontier Airlines Inc.', 'Allegiant Air',
#        'Hawaiian Airlines Inc.', 'Envoy Air', 'Spirit Air Lines',
#        'PSA Airlines Inc.', 'SkyWest Airlines Inc.', 'Horizon Air',
#        'United Air Lines Inc.', 'Southwest Airlines Co.',
#        'Mesa Airlines Inc.', 'Republic Airline',
#        'ExpressJet Airlines LLC', 'ExpressJet Airlines Inc.',
#        'Virgin America', 'US Airways Inc.', 'AirTran Airways Corporation',
#        'American Eagle Airlines Inc.', 'Pinnacle Airlines Inc.',
#        'Atlantic Southeast Airlines', 'Continental Air Lines Inc.',
#        'Comair Inc.', 'Northwest Airlines Inc.', 'Aloha Airlines Inc.',
#        'ATA Airlines d/b/a ATA', 'Independence Air',
#        'America West Airlines Inc.', 'Atlantic Coast Airlines'],
#       dtype=object)

# %%
airline_clean_df = airline_clean_df.rename(columns={"arr_flights":"Total Flights", "arr_del15":"Delays", "arr_cancelled":"Cancelled", "carrier_name":"Airline"})
airline_clean_df.head()
# Out:
#    year  month carrier            Airline airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  Total Flights  Delays  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...          136.0     7.0
# 1             Albany, GA: Southwest Georgia Regional           91.0    16.0
# 2                  Nantucket, MA: Nantucket Memorial           19.0     2.0
# 3           Alexandria, LA: Alexandria International           88.0    14.0
# 4        Augusta, GA: Augusta Regional at Bush Field          181.0    19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  Cancelled  \
# 0        5.95        0.00  ...          0.0              1.00        0.0
# 1        7.38        0.00  ...          0.0              6.09        0.0
# 2        0.13        0.00  ...          0.0              0.88        1.0
# 3        7.26        0.76  ...          0.0              1.64        0.0
# 4       13.84        0.00  ...          0.0              2.09        0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %%
total_flights = airline_clean_df.groupby(["Airline"]).sum()["Total Flights"]
total_flights_df = pd.DataFrame(total_flights)
total_flights_df.sort_values(by=['Total Flights'], inplace=True, ascending=False)
total_flights_df
# Out:
#                               Total Flights
# Airline
# Southwest Airlines Co.           22053649.0
# Delta Air Lines Inc.             13690394.0
# American Airlines Inc.           12971636.0
# SkyWest Airlines Inc.            11454934.0
# United Air Lines Inc.             9254401.0
# ExpressJet Airlines Inc.          7113659.0
# US Airways Inc.                   5188611.0
# American Eagle Airlines Inc.      5184465.0
# JetBlue Airways                   4027204.0
# Alaska Airlines Inc.              3237917.0
# Northwest Airlines Inc.           2767548.0
# Atlantic Southeast Airlines       2526761.0
# Continental Air Lines Inc.        2447163.0
# Mesa Airlines Inc.                2434549.0
# AirTran Airways Corporation       2427762.0
# Comair Inc.                       1765826.0
# Frontier Airlines Inc.            1665544.0
# Envoy Air                         1617456.0
# Hawaiian Airlines Inc.            1233675.0
# Republic Airline                  1228239.0
# Pinnacle Airlines Inc.            1222144.0
# Spirit Air Lines                  1210863.0
# Endeavor Air Inc.                 1077395.0
# PSA Airlines Inc.                  919041.0
# America West Airlines Inc.         503162.0
# Allegiant Air                      464450.0
# Virgin America                     389059.0
# Atlantic Coast Airlines            374247.0
# Independence Air                   196436.0
# ATA Airlines d/b/a ATA             181463.0
# Horizon Air                        150656.0
# ExpressJet Airlines LLC            149209.0
# Aloha Airlines Inc.                 89547.0

# %%
total_flights_bar = total_flights_df.plot(kind="bar", figsize=(18,12),
                                linewidth=10)

plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
total_flights_bar.set_xlabel('Airline', fontsize=18)
total_flights_bar.set_ylabel('Total Number of Flights', fontsize=18)

# Save the figure
plt.savefig("Output Images/Total Flights.png")

# Show plot
plt.show()

# %%
total_cancelled = pd.DataFrame(airline_clean_df.groupby(["Airline"]).sum()["Cancelled"])
total_cancelled_df = pd.DataFrame(total_cancelled)
total_cancelled_df.sort_values(by=['Cancelled'], inplace=True, ascending=False)
total_cancelled_df
# Out:
#                               Cancelled
# Airline
# Southwest Airlines Co.         339192.0
# American Airlines Inc.         265038.0
# SkyWest Airlines Inc.          239172.0
# ExpressJet Airlines Inc.       191983.0
# American Eagle Airlines Inc.   178259.0
# Delta Air Lines Inc.           156693.0
# United Air Lines Inc.          147098.0
# US Airways Inc.                 76464.0
# JetBlue Airways                 74452.0
# Mesa Airlines Inc.              73585.0
# Atlantic Southeast Airlines     68384.0
# Envoy Air                       63664.0
# Comair Inc.                     58035.0
# Alaska Airlines Inc.            41366.0
# Republic Airline                37491.0
# Northwest Airlines Inc.         33856.0
# Pinnacle Airlines Inc.          33121.0
# PSA Airlines Inc.               30774.0
# Spirit Air Lines                27349.0
# AirTran Airways Corporation     23771.0
# Allegiant Air                   20861.0
# Continental Air Lines Inc.      20394.0
# Frontier Airlines Inc.          20324.0
# Endeavor Air Inc.               19188.0
# Atlantic Coast Airlines         11960.0
# ExpressJet Airlines LLC          8173.0
# America West Airlines Inc.       6465.0
# Hawaiian Airlines Inc.           5600.0
# Independence Air                 4195.0
# Virgin America                   3550.0
# Horizon Air                      2991.0
# ATA Airlines d/b/a ATA           1862.0
# Aloha Airlines Inc.              1175.0

# %%
total_cancelled_bar = total_cancelled_df.plot(kind="bar", figsize=(18,12),
                                linewidth=10)

plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
total_cancelled_bar.set_xlabel('Airline', fontsize=18)
total_cancelled_bar.set_ylabel('Total Flights Cancelled', fontsize=18)

# Save the figure
plt.savefig("Output Images/Total Cancellations.png")

# Show plot
plt.show()

# %%
percent_cancelled = airline_clean_df.groupby(["Airline"]).sum()["Cancelled"] / airline_clean_df.groupby(["Airline"]).sum()["Total Flights"] * 100
percent_cancelled_df = pd.DataFrame(percent_cancelled)
percent_cancelled_df = percent_cancelled_df.rename(columns={0:"Percent Cancelled"})
percent_cancelled_df.sort_values(by=['Percent Cancelled'], inplace=True, ascending=False)
percent_cancelled_df
# Out:
#                               Percent Cancelled
# Airline
# ExpressJet Airlines LLC                5.477552
# Allegiant Air                          4.491549
# Envoy Air                              3.936058
# American Eagle Airlines Inc.           3.438330
# PSA Airlines Inc.                      3.348490
# Comair Inc.                            3.286564
# Atlantic Coast Airlines                3.195750
# Republic Airline                       3.052419
# Mesa Airlines Inc.                     3.022531
# Pinnacle Airlines Inc.                 2.710073
# Atlantic Southeast Airlines            2.706390
# ExpressJet Airlines Inc.               2.698794
# Spirit Air Lines                       2.258637
# Independence Air                       2.135556
# SkyWest Airlines Inc.                  2.087939
# American Airlines Inc.                 2.043212
# Horizon Air                            1.985318
# JetBlue Airways                        1.848727
# Endeavor Air Inc.                      1.780962
# United Air Lines Inc.                  1.589492
# Southwest Airlines Co.                 1.538031
# US Airways Inc.                        1.473689
# Aloha Airlines Inc.                    1.312160
# America West Airlines Inc.             1.284874
# Alaska Airlines Inc.                   1.277550
# Northwest Airlines Inc.                1.223321
# Frontier Airlines Inc.                 1.220262
# Delta Air Lines Inc.                   1.144547
# ATA Airlines d/b/a ATA                 1.026104
# AirTran Airways Corporation            0.979132
# Virgin America                         0.912458
# Continental Air Lines Inc.             0.833373
# Hawaiian Airlines Inc.                 0.453928

# %%
percent_cancelled_bar = percent_cancelled_df.plot(kind="bar", figsize=(18,12),
                                linewidth=10)

plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
percent_cancelled_bar.set_xlabel('Airline', fontsize=18)
percent_cancelled_bar.set_ylabel("Percent of Flights Canceled (%)", fontsize=18)



# Save the figure
plt.savefig("Output Images/Percent Cancelled.png")

# Show plot
plt.show()

# %%
total_delayed = airline_clean_df.groupby(["Airline"]).sum()["Delays"]
total_delayed_df = pd.DataFrame(total_delayed)
total_delayed_df.sort_values(by=['Delays'], inplace=True, ascending=False)
total_delayed_df
# Out:
#                                  Delays
# Airline
# Southwest Airlines Co.        4053401.0
# American Airlines Inc.        2609248.0
# Delta Air Lines Inc.          2179117.0
# SkyWest Airlines Inc.         1984694.0
# United Air Lines Inc.         1814691.0
# ExpressJet Airlines Inc.      1529090.0
# American Eagle Airlines Inc.  1129165.0
# US Airways Inc.                997160.0
# JetBlue Airways                953638.0
# Atlantic Southeast Airlines    618201.0
# Northwest Airlines Inc.        610029.0
# Alaska Airlines Inc.           545441.0
# Continental Air Lines Inc.     537252.0
# AirTran Airways Corporation    486307.0
# Mesa Airlines Inc.             470388.0
# Comair Inc.                    394146.0
# Frontier Airlines Inc.         369671.0
# Envoy Air                      308268.0
# Spirit Air Lines               245107.0
# Pinnacle Airlines Inc.         220024.0
# Republic Airline               192090.0
# PSA Airlines Inc.              152981.0
# Endeavor Air Inc.              136730.0
# Allegiant Air                  105195.0
# Hawaiian Airlines Inc.         103874.0
# America West Airlines Inc.      96342.0
# Virgin America                  79576.0
# Atlantic Coast Airlines         79078.0
# Independence Air                38823.0
# ATA Airlines d/b/a ATA          35298.0
# ExpressJet Airlines LLC         29672.0
# Horizon Air                     20694.0
# Aloha Airlines Inc.              6374.0

# %%
total_delayed_bar = total_delayed_df.plot(kind="bar", figsize=(18,12),
                                linewidth=10)

plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
total_delayed_bar.set_xlabel('Airline', fontsize=18)
total_delayed_bar.set_ylabel('Number of Flights Delayed', fontsize=18)


# Save the figure
plt.savefig("Output Images/Total Delayed.png")

# Show plot
plt.show()

# %%
percent_delayed = airline_clean_df.groupby(["Airline"]).sum()["Delays"] / airline_clean_df.groupby(["Airline"]).sum()["Total Flights"] * 100
percent_delayed_df = pd.DataFrame(percent_delayed)
percent_delayed_df = percent_delayed_df.rename(columns={0:"Percent Delayed"})
percent_delayed_df.sort_values(by=['Percent Delayed'], inplace=True, ascending=False)
percent_delayed_df
# Out:
#                               Percent Delayed
# Airline
# Atlantic Southeast Airlines         24.466145
# JetBlue Airways                     23.679903
# Allegiant Air                       22.649370
# Comair Inc.                         22.320772
# Frontier Airlines Inc.              22.195211
# Northwest Airlines Inc.             22.042219
# Continental Air Lines Inc.          21.954075
# American Eagle Airlines Inc.        21.779779
# ExpressJet Airlines Inc.            21.495126
# Atlantic Coast Airlines             21.129895
# Virgin America                      20.453453
# Spirit Air Lines                    20.242340
# American Airlines Inc.              20.115026
# AirTran Airways Corporation         20.031082
# ExpressJet Airlines LLC             19.886200
# Independence Air                    19.763689
# United Air Lines Inc.               19.608951
# ATA Airlines d/b/a ATA              19.451899
# Mesa Airlines Inc.                  19.321361
# US Airways Inc.                     19.218245
# America West Airlines Inc.          19.147312
# Envoy Air                           19.058818
# Southwest Airlines Co.              18.379729
# Pinnacle Airlines Inc.              18.003116
# SkyWest Airlines Inc.               17.326106
# Alaska Airlines Inc.                16.845429
# PSA Airlines Inc.                   16.645721
# Delta Air Lines Inc.                15.917124
# Republic Airline                    15.639464
# Horizon Air                         13.735928
# Endeavor Air Inc.                   12.690796
# Hawaiian Airlines Inc.               8.419884
# Aloha Airlines Inc.                  7.118050

# %%
percent_delayed_bar = percent_delayed_df.plot(kind="bar", figsize=(18,12),
                                linewidth=10)

plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
percent_delayed_bar.set_xlabel('Airline', fontsize=18)
percent_delayed_bar.set_ylabel("Percent of Flights Delayed (%)", fontsize=18)

# Save the figure
plt.savefig("Output Images/Percent Delayed.png")

# Show plot
plt.show()
